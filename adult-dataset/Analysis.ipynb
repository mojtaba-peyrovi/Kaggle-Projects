# %% [markdown]
# link: https://archive.ics.uci.edu/ml/datasets/Adult

# %%
import pandas as pd
import numpy as np

#visualisation
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('adult.data',header=None,\
                names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship:',\
                      'race','sex','capital-gain','capital-loss','hours-per-week','native-country','class'])
df_test = pd.read_csv('adult.test',header=None,\
                     names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship:',\
                      'race','sex','capital-gain','capital-loss','hours-per-week','native-country','class'])

# %%
df_train.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation   relationship:    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df_test.drop(index=0,inplace=True)

# %%
df_train.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
all_data=[df_train,df_test]

# %%
print('test')
print(df_test.isnull().sum())
print('>'* 40)
print('train')
print(df_train.isnull().sum())
  # no NaN values
# Out:
# test
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship:     0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class             0
# dtype: int64
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# train
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship:     0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class             0
# dtype: int64

# %%
df_train
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
len(df_train['native-country'].str.contains('Iran'))
# Out:
# 32561

# %%
df_train[['native-country','education-num']].groupby(['native-country'], as_index=False).mean().sort_values(by='education-num', ascending=False)
# Out:
#                  native-country  education-num
# 36                       Taiwan      13.294118
# 19                        India      12.430000
# 20                         Iran      12.395349
# 10                       France      12.241379
# 24                        Japan      11.435484
# 3                         China      11.120000
# 9                       England      11.011111
# 11                      Germany      10.985401
# 37                     Thailand      10.944444
# 35                        South      10.912500
# 30                  Philippines      10.868687
# 18                      Hungary      10.769231
# 2                        Canada      10.652893
# 17                         Hong      10.600000
# 0                             ?      10.598628
# 28   Outlying-US(Guam-USVI-etc)      10.285714
# 34                     Scotland      10.250000
# 39                United-States      10.169455
# 31                       Poland      10.100000
# ...

# %%
df_train[df_train['native-country'].notnull() & (df_train['education-num'] == 13)]
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 4       28            Private  338409   Bachelors             13
# 9       42            Private  159449   Bachelors             13
# 11      30          State-gov  141297   Bachelors             13
# 12      23            Private  122272   Bachelors             13
# 25      56          Local-gov  216851   Bachelors             13
# 32      45            Private  386940   Bachelors             13
# 41      53   Self-emp-not-inc   88506   Bachelors             13
# 42      24            Private  172987   Bachelors             13
# 45      57        Federal-gov  337895   Bachelors             13
# 53      50        Federal-gov  251585   Bachelors             13
# 60      30            Private   59496   Bachelors             13
# ...

# %%
df_train['native-country'].str.contanis("Iran")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-498f4904fb20> in <module>()
# ----> 1 df_train['native-country'].str.contanis("Iran")
#
# AttributeError: 'StringMethods' object has no attribute 'contanis'
